# %% [markdown]
# A) Look for the missing values in all the columns and either impute them (replace with mean,
# median, or mode) or drop them. Justify your action for this task.

# %% [markdown]
# B)Take off the units from some of the qualities and leave only the numerical numbers (remove CC from "Engine," lakh from "New Price," bhp from "Power," and kmpl from "Mileage").

# %%
#importing all the required libraries
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from datetime import datetime

# %%
#Reading the dataset 
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 1              46000    Petrol       Manual      First    13 km/kg  1199 CC
# 2              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 3              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
# 4              86999    Diesel       Manual      First  23.08 kmpl  1461 CC
#
#        Power  Seats  New_Price  Price
# 0  126.2 bhp    5.0        NaN  12.50
# 1   88.7 bhp    5.0  8.61 Lakh   4.50
# 2  88.76 bhp    7.0        NaN   6.00
# 3  140.8 bhp    5.0        NaN  17.74
# 4   63.1 bhp    5.0        NaN   3.50

# %%
#checking for null values in the data frame
null_data = data.isnull().sum()
print(null_data)
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  38
# New_Price            5032
# Price                   0
# dtype: int64

# %%
#dropping New_Price column because it has more NULL values compared to other numeric columns
data = data.drop('New_Price', axis=1)

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 1              46000    Petrol       Manual      First    13 km/kg  1199 CC
# 2              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 3              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
# 4              86999    Diesel       Manual      First  23.08 kmpl  1461 CC
#
#        Power  Seats  Price
# 0  126.2 bhp    5.0  12.50
# 1   88.7 bhp    5.0   4.50
# 2  88.76 bhp    7.0   6.00
# 3  140.8 bhp    5.0  17.74
# 4   63.1 bhp    5.0   3.50

# %%
#removing characters after interger values in the above columns
data['Mileage']=data['Mileage'].str.split(' ').str[0]
data['Engine']=data['Engine'].str.split(' ').str[0]
data['Power']=data['Power'].str.split(' ').str[0]
data['Seats']=data['Seats'].fillna(0)

# %%
# converting string columns values to float 
data['Mileage'] = data['Mileage']. astype(float)
data['Engine'] = data['Engine']. astype(float)
data['Power'] = data['Power']. astype(float)
data['Seats'] = data['Seats'] . astype(float)

# %%
#replacing the NULL values with mean

numeric_columns = ['Mileage', 'Engine', 'Power', 'Price','Seats']
imputer = SimpleImputer(strategy='mean')
data[numeric_columns] = imputer.fit_transform(data[numeric_columns])

# %%
#checking for null values in the data frame after dropping and adding mean values in the place of NULL 
data.isnull().sum()
# Out:
# Unnamed: 0           0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
data
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0                 41000    Diesel       Manual      First    19.67  1582.0
# 1                 46000    Petrol       Manual      First    13.00  1199.0
# 2                 87000    Diesel       Manual      First    20.77  1248.0
# 3                 40670    Diesel    Automatic     Second    15.20  1968.0
# 4                 86999    Diesel       Manual      First    23.08  1461.0
# ...                 ...       ...          ...        ...      ...     ...
# 5842              27365    Diesel       Manual      First    28.40  1248.0
# 5843             100000    Diesel       Manual      First    24.40  1120.0
# 5844              55000    Diesel       Manual     Second    14.00  2498.0
# 5845              46000    Petrol       Manual      First    18.90   998.0
# 5846              47000    Diesel       Manual      First    25.44   936.0
#
#        Power  Seats  Price
# 0     126.20    5.0  12.50
# 1      88.70    5.0   4.50
# 2      88.76    7.0   6.00
# 3     140.80    5.0  17.74
# 4      63.10    5.0   3.50
# ...      ...    ...    ...
# 5842   74.00    5.0   4.75
# 5843   71.00    5.0   4.00
# 5844  112.00    8.0   2.90
# 5845   67.10    5.0   2.65
# 5846   57.60    5.0   2.50
#
# [5847 rows x 13 columns]

# %% [markdown]
# C) Change the categorical variables (“Fuel_Type” and “Transmission”) into numerical one hot
# encoded value

# %%
data = pd.get_dummies(data, columns=['Fuel_Type', 'Transmission'], prefix=['Fuel','Transmission'])

# %%
data
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0                 41000      First    19.67  1582.0  126.20    5.0  12.50
# 1                 46000      First    13.00  1199.0   88.70    5.0   4.50
# 2                 87000      First    20.77  1248.0   88.76    7.0   6.00
# 3                 40670     Second    15.20  1968.0  140.80    5.0  17.74
# 4                 86999      First    23.08  1461.0   63.10    5.0   3.50
# ...                 ...        ...      ...     ...     ...    ...    ...
# 5842              27365      First    28.40  1248.0   74.00    5.0   4.75
# 5843             100000      First    24.40  1120.0   71.00    5.0   4.00
# 5844              55000     Second    14.00  2498.0  112.00    8.0   2.90
# 5845              46000      First    18.90   998.0   67.10    5.0   2.65
# 5846              47000      First    25.44   936.0   57.60    5.0   2.50
#
#       Fuel_Diesel  Fuel_Electric  Fuel_Petrol  Transmission_Automatic  \
# 0            True          False        False                   False
# 1           False          False         True                   False
# 2            True          False        False                   False
# 3            True          False        False                    True
# 4            True          False        False                   False
# ...           ...            ...          ...                     ...
# 5842         True          False        False                   False
# 5843         True          False        False                   False
# 5844         True          False        False                   False
# 5845        False          False         True                   False
# 5846         True          False        False                   False
#
#       Transmission_Manual
# 0                    True
# 1                    True
# 2                    True
# 3                   False
# 4                    True
# ...                   ...
# 5842                 True
# 5843                 True
# 5844                 True
# 5845                 True
# 5846                 True
#
# [5847 rows x 16 columns]

# %%
col = ['Fuel_Diesel','Fuel_Electric','Fuel_Petrol','Transmission_Automatic','Transmission_Manual']
#converting =the columns to integer values i.e 0's and 1's
data[col] = data[col].astype(int)

# %%
data
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0                 41000      First    19.67  1582.0  126.20    5.0  12.50
# 1                 46000      First    13.00  1199.0   88.70    5.0   4.50
# 2                 87000      First    20.77  1248.0   88.76    7.0   6.00
# 3                 40670     Second    15.20  1968.0  140.80    5.0  17.74
# 4                 86999      First    23.08  1461.0   63.10    5.0   3.50
# ...                 ...        ...      ...     ...     ...    ...    ...
# 5842              27365      First    28.40  1248.0   74.00    5.0   4.75
# 5843             100000      First    24.40  1120.0   71.00    5.0   4.00
# 5844              55000     Second    14.00  2498.0  112.00    8.0   2.90
# 5845              46000      First    18.90   998.0   67.10    5.0   2.65
# 5846              47000      First    25.44   936.0   57.60    5.0   2.50
#
#       Fuel_Diesel  Fuel_Electric  Fuel_Petrol  Transmission_Automatic  \
# 0               1              0            0                       0
# 1               0              0            1                       0
# 2               1              0            0                       0
# 3               1              0            0                       1
# 4               1              0            0                       0
# ...           ...            ...          ...                     ...
# 5842            1              0            0                       0
# 5843            1              0            0                       0
# 5844            1              0            0                       0
# 5845            0              0            1                       0
# 5846            1              0            0                       0
#
#       Transmission_Manual
# 0                       1
# 1                       1
# 2                       1
# 3                       0
# 4                       1
# ...                   ...
# 5842                    1
# 5843                    1
# 5844                    1
# 5845                    1
# 5846                    1
#
# [5847 rows x 16 columns]

# %% [markdown]
# D) Create one more feature and add this column to the dataset (you can use mutate function in
# R for this). For example, you can calculate the current age of the car by subtracting “Year” value
# from the current year

# %%
#Adding a column of car age by using current age and manufactured year
current_year = datetime.now().year
data['Current_Age'] = current_year - data['Year']

# %%
data
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0                 41000      First    19.67  1582.0  126.20    5.0  12.50
# 1                 46000      First    13.00  1199.0   88.70    5.0   4.50
# 2                 87000      First    20.77  1248.0   88.76    7.0   6.00
# 3                 40670     Second    15.20  1968.0  140.80    5.0  17.74
# 4                 86999      First    23.08  1461.0   63.10    5.0   3.50
# ...                 ...        ...      ...     ...     ...    ...    ...
# 5842              27365      First    28.40  1248.0   74.00    5.0   4.75
# 5843             100000      First    24.40  1120.0   71.00    5.0   4.00
# 5844              55000     Second    14.00  2498.0  112.00    8.0   2.90
# 5845              46000      First    18.90   998.0   67.10    5.0   2.65
# 5846              47000      First    25.44   936.0   57.60    5.0   2.50
#
#       Fuel_Diesel  Fuel_Electric  Fuel_Petrol  Transmission_Automatic  \
# 0               1              0            0                       0
# 1               0              0            1                       0
# 2               1              0            0                       0
# 3               1              0            0                       1
# 4               1              0            0                       0
# ...           ...            ...          ...                     ...
# 5842            1              0            0                       0
# 5843            1              0            0                       0
# 5844            1              0            0                       0
# 5845            0              0            1                       0
# 5846            1              0            0                       0
#
#       Transmission_Manual  Current_Age
# 0                       1            9
# 1                       1           13
# 2                       1           12
# 3                       0           11
# 4                       1           11
# ...                   ...          ...
# 5842                    1           10
# 5843                    1            9
# 5844                    1           12
# 5845                    1           11
# 5846                    1           13
#
# [5847 rows x 17 columns]

# %%
df=pd.read_csv("train.csv")

# %% [markdown]
# e) Perform select, filter, rename, mutate, arrange and summarize with group by operations (or their equivalent operations in python) on this dataset.

# %%
# Select rows
df[['Name','Mileage']]
# Out:
#                                   Name     Mileage
# 0     Hyundai Creta 1.6 CRDi SX Option  19.67 kmpl
# 1                         Honda Jazz V    13 km/kg
# 2                    Maruti Ertiga VDI  20.77 kmpl
# 3      Audi A4 New 2.0 TDI Multitronic   15.2 kmpl
# 4               Nissan Micra Diesel XV  23.08 kmpl
# ...                                ...         ...
# 5842                  Maruti Swift VDI   28.4 kmpl
# 5843          Hyundai Xcent 1.1 CRDi S   24.4 kmpl
# 5844             Mahindra Xylo D4 BSIV   14.0 kmpl
# 5845                Maruti Wagon R VXI   18.9 kmpl
# 5846             Chevrolet Beat Diesel  25.44 kmpl
#
# [5847 rows x 2 columns]

# %%
# Filter rows

df[df['Kilometers_Driven']>30000]
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5841        6013             Honda Amaze VX i-DTEC  Coimbatore  2015
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 41000    Diesel       Manual      First  19.67 kmpl
# 1                 46000    Petrol       Manual      First    13 km/kg
# 2                 87000    Diesel       Manual      First  20.77 kmpl
# 3                 40670    Diesel    Automatic     Second   15.2 kmpl
# 4                 86999    Diesel       Manual      First  23.08 kmpl
# ...                 ...       ...          ...        ...         ...
# 5841              70602    Diesel       Manual      First   25.8 kmpl
# 5843             100000    Diesel       Manual      First   24.4 kmpl
# 5844              55000    Diesel       Manual     Second   14.0 kmpl
# 5845              46000    Petrol       Manual      First   18.9 kmpl
# 5846              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0     1582 CC  126.2 bhp    5.0        NaN  12.50
# 1     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 2     1248 CC  88.76 bhp    7.0        NaN   6.00
# 3     1968 CC  140.8 bhp    5.0        NaN  17.74
# 4     1461 CC   63.1 bhp    5.0        NaN   3.50
# ...       ...        ...    ...        ...    ...
# 5841  1498 CC   98.6 bhp    5.0        NaN   4.83
# 5843  1120 CC     71 bhp    5.0        NaN   4.00
# 5844  2498 CC    112 bhp    8.0        NaN   2.90
# 5845   998 CC   67.1 bhp    5.0        NaN   2.65
# 5846   936 CC   57.6 bhp    5.0        NaN   2.50
#
# [4605 rows x 14 columns]

# %%
# Rename column

df.rename(columns={'Name': 'Model_Name'})
# Out:
#       Unnamed: 0                        Model_Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 41000    Diesel       Manual      First  19.67 kmpl
# 1                 46000    Petrol       Manual      First    13 km/kg
# 2                 87000    Diesel       Manual      First  20.77 kmpl
# 3                 40670    Diesel    Automatic     Second   15.2 kmpl
# 4                 86999    Diesel       Manual      First  23.08 kmpl
# ...                 ...       ...          ...        ...         ...
# 5842              27365    Diesel       Manual      First   28.4 kmpl
# 5843             100000    Diesel       Manual      First   24.4 kmpl
# 5844              55000    Diesel       Manual     Second   14.0 kmpl
# 5845              46000    Petrol       Manual      First   18.9 kmpl
# 5846              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price  Price_Half
# 0     1582 CC  126.2 bhp    5.0        NaN  12.50       6.250
# 1     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50       2.250
# 2     1248 CC  88.76 bhp    7.0        NaN   6.00       3.000
# 3     1968 CC  140.8 bhp    5.0        NaN  17.74       8.870
# 4     1461 CC   63.1 bhp    5.0        NaN   3.50       1.750
# ...       ...        ...    ...        ...    ...         ...
# 5842  1248 CC     74 bhp    5.0  7.88 Lakh   4.75       2.375
# 5843  1120 CC     71 bhp    5.0        NaN   4.00       2.000
# 5844  2498 CC    112 bhp    8.0        NaN   2.90       1.450
# 5845   998 CC   67.1 bhp    5.0        NaN   2.65       1.325
# 5846   936 CC   57.6 bhp    5.0        NaN   2.50       1.250
#
# [5847 rows x 15 columns]

# %%
df
# Out:
#       Unnamed: 0                        Model_Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 41000    Diesel       Manual      First  19.67 kmpl
# 1                 46000    Petrol       Manual      First    13 km/kg
# 2                 87000    Diesel       Manual      First  20.77 kmpl
# 3                 40670    Diesel    Automatic     Second   15.2 kmpl
# 4                 86999    Diesel       Manual      First  23.08 kmpl
# ...                 ...       ...          ...        ...         ...
# 5842              27365    Diesel       Manual      First   28.4 kmpl
# 5843             100000    Diesel       Manual      First   24.4 kmpl
# 5844              55000    Diesel       Manual     Second   14.0 kmpl
# 5845              46000    Petrol       Manual      First   18.9 kmpl
# 5846              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price  Price_Half
# 0     1582 CC  126.2 bhp    5.0        NaN  12.50       6.250
# 1     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50       2.250
# 2     1248 CC  88.76 bhp    7.0        NaN   6.00       3.000
# 3     1968 CC  140.8 bhp    5.0        NaN  17.74       8.870
# 4     1461 CC   63.1 bhp    5.0        NaN   3.50       1.750
# ...       ...        ...    ...        ...    ...         ...
# 5842  1248 CC     74 bhp    5.0  7.88 Lakh   4.75       2.375
# 5843  1120 CC     71 bhp    5.0        NaN   4.00       2.000
# 5844  2498 CC    112 bhp    8.0        NaN   2.90       1.450
# 5845   998 CC   67.1 bhp    5.0        NaN   2.65       1.325
# 5846   936 CC   57.6 bhp    5.0        NaN   2.50       1.250
#
# [5847 rows x 15 columns]

# %%
# Mutate (add) a new column

df['Price_Half'] = df['Price'] / 2

# %%
df
# Out:
#       Unnamed: 0                        Model_Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 41000    Diesel       Manual      First  19.67 kmpl
# 1                 46000    Petrol       Manual      First    13 km/kg
# 2                 87000    Diesel       Manual      First  20.77 kmpl
# 3                 40670    Diesel    Automatic     Second   15.2 kmpl
# 4                 86999    Diesel       Manual      First  23.08 kmpl
# ...                 ...       ...          ...        ...         ...
# 5842              27365    Diesel       Manual      First   28.4 kmpl
# 5843             100000    Diesel       Manual      First   24.4 kmpl
# 5844              55000    Diesel       Manual     Second   14.0 kmpl
# 5845              46000    Petrol       Manual      First   18.9 kmpl
# 5846              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price  Price_Half
# 0     1582 CC  126.2 bhp    5.0        NaN  12.50       6.250
# 1     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50       2.250
# 2     1248 CC  88.76 bhp    7.0        NaN   6.00       3.000
# 3     1968 CC  140.8 bhp    5.0        NaN  17.74       8.870
# 4     1461 CC   63.1 bhp    5.0        NaN   3.50       1.750
# ...       ...        ...    ...        ...    ...         ...
# 5842  1248 CC     74 bhp    5.0  7.88 Lakh   4.75       2.375
# 5843  1120 CC     71 bhp    5.0        NaN   4.00       2.000
# 5844  2498 CC    112 bhp    8.0        NaN   2.90       1.450
# 5845   998 CC   67.1 bhp    5.0        NaN   2.65       1.325
# 5846   936 CC   57.6 bhp    5.0        NaN   2.50       1.250
#
# [5847 rows x 15 columns]

# %%
#performing arrange operation to a column

df.sort_values(by='Mileage', ascending=False)
# Out:
#       Unnamed: 0                                 Model_Name   Location  Year  \
# 537          557                           Audi TT 2.0 TFSI      Delhi  2013
# 1247        1288                           Audi TT 2.0 TFSI      Kochi  2014
# 3470        3580  Mercedes-Benz CLS-Class 2006-2010 350 CDI  Hyderabad  2010
# 4386        4519                     Maruti Grand Vitara MT     Mumbai  2008
# 3875        4001               Honda Accord 2.4 Inspire M/T     Mumbai  2012
# ...          ...                                        ...        ...   ...
# 683          707        Mercedes-Benz M-Class ML 350 4Matic       Pune  2014
# 4172        4302                     Hyundai Santro Xing GL      Delhi  2012
# 5225        5374        Mercedes-Benz M-Class ML 350 4Matic  Ahmedabad  2012
# 4313        4446                       Mahindra E Verito D4    Chennai  2016
# 4762        4904                  Toyota Prius 2009-2016 Z4     Mumbai  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type   Mileage   Engine  \
# 537               12100    Petrol    Automatic      First  9.9 kmpl  1984 CC
# 1247              14262    Petrol    Automatic      First  9.9 kmpl  1984 CC
# 3470              29000    Diesel    Automatic      First  9.9 kmpl  3498 CC
# 4386              46810    Petrol       Manual      First  9.8 kmpl  1995 CC
# 3875              42000    Petrol       Manual      First  9.8 kmpl  2354 CC
# ...                 ...       ...          ...        ...       ...      ...
# 683              120000    Diesel    Automatic      First  0.0 kmpl  2987 CC
# 4172              61449    Petrol       Manual      First  0.0 kmpl  1086 CC
# 5225              66000    Diesel    Automatic      First  0.0 kmpl  2987 CC
# 4313              50000  Electric    Automatic      First       NaN    72 CC
# 4762              44000  Electric    Automatic      First       NaN  1798 CC
#
#            Power  Seats   New_Price  Price  Price_Half
# 537    207.8 bhp    2.0         NaN  29.50      14.750
# 1247   207.8 bhp    2.0         NaN  27.35      13.675
# 3470  271.72 bhp    4.0         NaN  32.00      16.000
# 4386   163.5 bhp    5.0         NaN   3.95       1.975
# 3875     180 bhp    5.0         NaN   6.25       3.125
# ...          ...    ...         ...    ...         ...
# 683      165 bhp    5.0         NaN  30.00      15.000
# 4172      62 bhp    5.0         NaN   2.15       1.075
# 5225     165 bhp    5.0         NaN  23.00      11.500
# 4313      41 bhp    5.0  13.58 Lakh  13.00       6.500
# 4762      73 bhp    5.0         NaN  12.75       6.375
#
# [5847 rows x 15 columns]

# %%
# Summarize with group by operations

df.groupby('Model_Name').agg({'Year': 'mean', 'Price': 'max'}).reset_index()
# Out:
#                           Model_Name         Year  Price
# 0     Ambassador Classic Nova Diesel  2003.000000   1.35
# 1          Audi A3 35 TDI Attraction  2014.000000  16.50
# 2             Audi A3 35 TDI Premium  2016.000000  19.25
# 3        Audi A3 35 TDI Premium Plus  2016.000000  18.90
# 4          Audi A3 35 TDI Technology  2017.000000  22.50
# ...                              ...          ...    ...
# 1799            Volvo XC60 D4 Summum  2012.000000  18.25
# 1800                   Volvo XC60 D5  2012.333333  32.50
# 1801       Volvo XC60 D5 Inscription  2014.000000  17.18
# 1802  Volvo XC90 2007-2015 D5 AT AWD  2014.000000  23.58
# 1803     Volvo XC90 2007-2015 D5 AWD  2014.000000  23.65
#
# [1804 rows x 3 columns]
